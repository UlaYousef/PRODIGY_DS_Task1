# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/fish.csv')
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df.head(10)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5   Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6   Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7   Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8   Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9   Bream   500.0     28.5     30.7     36.2  14.2266  4.9594

# %%
df.tail(10)
# Out:
#     Species  Weight  Length1  Length2  Length3  Height   Width
# 149   Smelt     9.8     10.7     11.2     12.4  2.0832  1.2772
# 150   Smelt     8.7     10.8     11.3     12.6  1.9782  1.2852
# 151   Smelt    10.0     11.3     11.8     13.1  2.2139  1.2838
# 152   Smelt     9.9     11.3     11.8     13.1  2.2139  1.1659
# 153   Smelt     9.8     11.4     12.0     13.2  2.2044  1.1484
# 154   Smelt    12.2     11.5     12.2     13.4  2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5  2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8  2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2  2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2  2.9322  1.8792

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.dtypes
# Out:
# Species     object
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object

# %%
df['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Species',y='Height',data=df,estimator='max')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Width',data=df,x='Species',estimator='max')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Species',y='Weight',data=df,estimator='max')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Species',y='Length1',data=df,estimator='max')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Species',y='Length2',data=df,estimator='max')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Species',y='Length3',data=df,estimator='max')
plt.show()

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
sns.set(palette="rainbow")
f, axes = plt.subplots(3, 2,figsize=(8,12))
sns.histplot(df['Weight'],ax = axes[0,0],kde=True)
sns.histplot(df['Length1'],ax=axes[0,1],kde=True)
sns.histplot(df['Length2'],ax=axes[1,0],kde=True)
sns.histplot(df['Length3'],ax=axes[1,1],kde=True)
sns.histplot(df['Height'],ax=axes[2,0],kde=True)
sns.histplot(df['Width'],ax=axes[2,1],kde=True)
plt.show()

# %%
from pandas.plotting import andrews_curves
plt.figure(figsize=(10,10))
andrews_curves(df,"Species")
plt.show()

# %%
sns.pairplot(df,hue='Species',palette='inferno')

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
sns.set(palette='viridis')
f,axes=plt.subplots(3,2,figsize=(25,10))
sns.boxplot(x=df['Species'],y=df['Weight'],ax=axes[0,0])
sns.boxplot(x=df['Species'],y=df['Length1'],ax=axes[0,1])
sns.boxplot(x=df['Species'],y=df['Length2'],ax=axes[1,0])
sns.boxplot(x=df['Species'],y=df['Length3'],ax=axes[1,1])
sns.boxplot(x=df['Species'],y=df['Height'],ax=axes[2,0])
sns.boxplot(x=df['Species'],y=df['Width'],ax=axes[2,1])
plt.show()

# %%
sns.set(palette='viridis')
f, axes = plt.subplots(3, 2,figsize=(20,8))
sns.violinplot(data=df, y="Weight",x='Species',ax= axes[0,0])
sns.violinplot(data=df, y="Length1",x='Species',ax= axes[0,1])
sns.violinplot(data=df, y="Length2",x='Species',ax= axes[1,0])
sns.violinplot(data=df, y="Length3",x='Species',ax= axes[1,1])
sns.violinplot(data=df, y="Height",x='Species',ax= axes[2,0])
sns.violinplot(data=df, y="Width",x='Species',ax= axes[2,1])
plt.show()

# %%
df1=df.corr()
sns.heatmap(df1,cmap='cool',annot=True,linewidth=0.7)
plt.show()
